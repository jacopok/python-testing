# %%
throws_green_d20 = [
    1, 15, 2, 3, 12, 15, 5, 9, 18, 13, 8, 3, 11, 15, 13, 9,
    11, 10, 11, 7, 8, 18, 7, 6, 11, 14, 10, 8, 5, 13, 10, 5, 13, 2, 6, 14, 2, 11,
    11,10,8,18,9,9,19, 1, 2, 12, 20, 18, 17, 18, 2, 2, 10, 12, 
    9, 11, 15, 12, 20, 1, 10, 11, 1, 6, 18, 14, 17, 
    13, 11, 10, 17,  14, 15, 17, 11, 8, 20, 8, 17, 16, 6, 9, 13, 
    19, 4, 5, 11, 15, 1, 14, 5, 20, 4, 11, 11, 16, 9, 8, 14
]

throws_green_d4 = [
    1, 4, 1, 4, 3, 1, 1, 3, 2, 3, 4, 1, 3, 1, 3, 3, 1, 
    1, 4, 3, 3, 1, 1, 4, 2, 1, 2, 4, 1, 2, 4, 3, 4, 1, 
    3, 3, 2, 3, 4, 4, 2, 4, 2, 2, 2, 3, 2, 4, 2, 1, 2, 
    1, 4, 1, 4, 4, 4, 2, 4, 2, 1, 3, 4, 4, 3, 1, 1, 2 
]

throws_4d4 = [
    14, 12, 13, 10, 9, 11, 12, 13, 8, 10, 11, 12, 10, 9, 8, 11, 
    6, 10, 12, 11, 9, 13, 11, 11, 14, 10, 7, 9, 8, 9, 14, 13, 
    14, 12, 10, 11, 10, 9, 10, 9, 7, 12, 12, 7, 14, 9
]

# %%
from collections import Counter
c = Counter(sorted(throws_4d4))
k, v = c.keys(), c.values()

# %%
plt.plot(k, v)
