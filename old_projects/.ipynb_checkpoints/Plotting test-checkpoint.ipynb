# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def f(x, y):
    z = x**2 + y**2
    return z

# %%
x = np.arange(30)
y = np.arange(30)
z = f(x, y)
print(z)
# Out:
# [   0    2    8   18   32   50   72   98  128  162  200  242  288  338
#   392  450  512  578  648  722  800  882  968 1058 1152 1250 1352 1458
#  1568 1682]

# %%
from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
from sympy.abc import x

# %%
f = Function('f')
dsolve(Derivative(f(x), x, x) + 9*f(x), f(x),
       ics = {f(0): 1, Derivative(f(x), x).subs(x, 0) : 1}).subs(x, 10).n(1000)
# Out:
# Eq(f(10), -0....)
